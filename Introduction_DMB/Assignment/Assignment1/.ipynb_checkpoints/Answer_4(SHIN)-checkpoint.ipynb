# %%
from IPython.display import Image, display

display(Image(filename='/Users/hunjunsin/Desktop/스크린샷 2024-09-12 오후 4.39.06.png'))

# %%
import numpy as np

# %%
a = np.array([5, 8, 3, 1 ,10 ,9 ,12])

k = np.diff(a)
t = np.sign(k)
l = np.diff(t)

print(a)
print(k)
print(t)
print(l)
# Out:
# [ 5  8  3  1 10  9 12]
# [ 3 -5 -2  9 -1  3]
# [ 1 -1 -1  1 -1  1]
# [-2  0  2 -2  2]

# %%
def local_max(arr):
    
    peaks =(np.diff(npx.sign(np.diff(arr))) < 0).nonzero()[0] + 1 
    
    return arr[peaks]

# %%
result = local_max(a)

# %%
print(result)
# Out:
# [ 8 10]

# %% [markdown]
# The Answer 4 is

# %%
def local_max(arr):
    
    peaks =(np.diff(npx.sign(np.diff(arr))) < 0).nonzero()[0] + 1 
    
    return arr[peaks]
