# %%
from IPython.display import Image, display

display(Image(filename='/Users/hunjunsin/Desktop/스크린샷 2024-09-12 오후 4.10.52.png'))

# %%
import numpy as np

# %% [markdown]
# Answer 3 is

# %%
def closest_value(arr, v):
    
    arr = np.array(arr)
    
    index = (np.abs(arr-v)).argmin()
    
    return arr[index]

# %%
a =[10, 3, 7, 8, 15]

# %%
closest_value(a, 4)
# Out:
# 3
