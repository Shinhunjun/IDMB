# %% [markdown]
# Answer for Question 4

# %%
import matplotlib.pyplot as plt

# %%
browsers = ['Chrome', 'Safari', 'Edge', 'Firefox', 'Samsung Internet', 'Opera']
market_share = [65.18, 18.55, 5.26, 2.74, 2.56, 2.15]

# %%
colors = ['gold','silver','yellowgreen', 'lightcoral', 'lightskyblue','pink']

# %%
explode = (0.1, 0, 0, 0, 0, 0)

# %%
plt.title('Browser market shares worldwide(2024)')
plt.pie(market_share, explode = explode, labels= browsers, colors= colors, autopct = '%1.1f%%', shadow= True, startangle=60, labeldistance=1.15)
plt.axis('equal')
# Out:
# (-1.2049559413880093,
#  1.104992935091161,
#  -1.1028878730430292,
#  1.0971120038946123)
