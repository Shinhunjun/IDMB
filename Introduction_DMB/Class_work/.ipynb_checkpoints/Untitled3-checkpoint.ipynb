# %%
# !pip3 install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import sys
print(sys.executable)  # 사용 중인 파이썬 경로 확인
import matplotlib
print(matplotlib.__file__)  # matplotlib 설치 경로 확인
# Out:
# /opt/anaconda3/bin/python
# /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py

# %%
x = [1, 2, 3, 4]
y = list(x**10 for x in x)

# %%
plt.plot(x, y)
